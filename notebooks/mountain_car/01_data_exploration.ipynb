# %% [markdown]
# # Mountain Car Data Exploration
#
# This notebook demonstrates how to use NotebookConfig to load all parameters from YAML files.

# %%
# Import NotebookConfig
import sys
sys.path.append('../..')
from src.utils.notebook_config import NotebookConfig

# Load configuration
cfg = NotebookConfig('mountain_car')

print("Configuration loaded successfully!")
print(f"System: {cfg.system_name}")

# %%
# Access configuration parameters
import numpy as np
from pathlib import Path

# Data paths from config
data_dir = Path(cfg['data.data_dir'])
roa_labels_file = Path(cfg['data.roa_labels_file'])
trajectories_dir = Path(cfg['data.trajectories_dir'])

print(f"Data directory: {data_dir}")
print(f"ROA labels file: {roa_labels_file}")
print(f"Trajectories directory: {trajectories_dir}")

# Visualization parameters
figsize = cfg['viz.figsize']
dpi = cfg['viz.dpi']
print(f"\nVisualization settings:")
print(f"  Figure size: {figsize}")
print(f"  DPI: {dpi}")
